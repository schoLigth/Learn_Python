# %% [markdown]
# # **Exercise 1**

# %%
# 1.1 Import numpy and transform the following list into a NumPy array
a = [10,39,10,20,40,21,55,23,66,76]
print(a)
# Out:
# [10, 39, 10, 20, 40, 21, 55, 23, 66, 76]

# %%
import numpy as np
aNum = np.array(a)

aNum
# Out:
# array([10, 39, 10, 20, 40, 21, 55, 23, 66, 76])

# %%
# 1.2 Select all values larger than 20 with boolean indexing
aNum [aNum > 20]
# Out:
# array([39, 40, 21, 55, 23, 66, 76])

# %%
# 1.3 Add the following list of values to a
b = [2,4,5]
a = np.append(aNum,b)
a
# Out:
# array([10, 39, 10, 20, 40, 21, 55, 23, 66, 76,  2,  4,  5])

# %%
# 1.4 compute mean and standard deviation of this array
print("std:", a.std())
print("mean:", a.mean())
# Out:
# std: 23.705291147808474
# mean: 28.53846153846154

# %%
# 1.5  multiply each value in list a by 2
# a = a * 2
a = a - 1
a
# Out:
# array([ 9, 38,  9, 19, 39, 20, 54, 22, 65, 75,  1,  3,  4])

# %% [markdown]
# # **Exercise 2**

# %%
data = {
        "Name":["Clara", "Tom", "Sarah", "John"],
        "Gender":["F","M","F","M"],
        "Age":[20,25,28,22]
        }

# %%
# 2.1 import pandas and create a dataframe from dictionary data
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#     Name Gender  Age
# 0  Clara      F   20
# 1    Tom      M   25
# 2  Sarah      F   28
# 3   John      M   22

# %%
# 2.2 Add a new column 'Grade' with the list grades to the dataframe
grades = [2,3,4,1]
df['Grades'] = grades
df
# Out:
#     Name Gender  Age  grades
# 0  Clara      F   20       2
# 1    Tom      M   25       3
# 2  Sarah      F   28       4
# 3   John      M   22       1

# %%
# 2.3 sort the entries of the dataframe by their age
df.sort_values(by='Grades')
# Out:
#     Name Gender  Age  grades
# 3   John      M   22       1
# 0  Clara      F   20       2
# 1    Tom      M   25       3
# 2  Sarah      F   28       4

# %%
# 2.4 compute the mean age
df['Age'].mean()
# Out:
# np.float64(23.75)

# %%
# 2.5 compute the mean age of all female persons
dfa = df[df['Gender'] == 'F']
dfa

print("Mean age of female:", dfa['Age'].mean())
# Out:
# Mean age of female: 24.0

# %% [markdown]
# # **Exercise 3**

# %%
data = {
        "Name":["Clara", "Tom", "Sarah"],
        "Gender":["F","M","F"],
        "Age":[20,25,28]
        }


data2 = {
        "Name":["Clara", "Tom", "John"],
        "Subject":["Physics","Politics","English"],
        "Grade":[2,1,3]
        }
df1 = pd.DataFrame(data)
df2 = pd.DataFrame(data2)

# %%
# 3.1 merge df1 and df2 on Name, try out left, right joins
df3 = df1.merge(df2)
df3
# Out:
#     Name Gender  Age   Subject  Grade
# 0  Clara      F   20   Physics      2
# 1    Tom      M   25  Politics      1

# %%
# 3.2 Compute the mean age per gender for df1 with a group-by
df4 = df3.groupby(by="Gender")
df4['Age'].mean()
# Out:
# Gender
# F    20.0
# M    25.0
# Name: Age, dtype: float64

# %% [markdown]
# # **Exercise 4**

# %%
# # Execute this cell to import pandas and load data
# import pandas as pd
# df = pd.read_csv('https://drive.google.com/uc?id=1Rzq2VqPVRM2kfMuh_jToJKzKUvBOC0vp')

# # some cleaning, we come to this topic later
# df['price'] = df['price'].str.replace('$','').str.replace(',','').astype(float)
# Out:
# <ipython-input-2-e846cf4fc00d>:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('$','').str.replace(',','').astype(float)

# %%
# Execute this cell to import pandas and load data
import pandas as pd
df = pd.read_csv('https://drive.google.com/uc?id=1Rzq2VqPVRM2kfMuh_jToJKzKUvBOC0vp')
df
# Out:
#              id   price neighbourhood_group_cleansed   latitude  longitude  \
# 0      28684898  $50.00                     Neukölln  52.473978  13.454423
# 1      22607348  $10.00           Treptow - Köpenick  52.468095  13.487103
# 2      21019199  $35.00                     Neukölln  52.481810  13.437268
# 3      21919556  $99.00                       Pankow  52.537269  13.416036
# 4       4820648  $39.00     Friedrichshain-Kreuzberg  52.491483  13.387362
# ...         ...     ...                          ...        ...        ...
# 13526  17783594  $38.00           Treptow - Köpenick  52.469634  13.588212
# 13527  28732723  $45.00                       Pankow  52.548687  13.448582
# 13528   7823323  $22.00                        Mitte  52.524995  13.336786
# 13529    901569  $40.00                       Pankow  52.530876  13.433975
# 13530  21608963  $45.00                     Neukölln  52.481689  13.431743
#
#        bathrooms  availability_30  beds  bedrooms  review_scores_value  \
# 0            1.0               18   2.0       2.0                  9.0
# 1            1.0                0   1.0       1.0                  9.0
# 2            1.0                0   1.0       1.0                  9.0
# 3            2.0                0   2.0       2.0                  NaN
# 4            1.0                0   1.0       1.0                  9.0
# ...          ...              ...   ...       ...                  ...
# 13526        1.0               18   2.0       2.0                  9.0
# 13527        1.0                0   1.0       1.0                  NaN
# 13528        2.0                0   1.0       1.0                  9.0
# 13529        1.0                5   1.0       1.0                 10.0
# 13530        1.0               16   1.0       1.0                  8.0
#
#        bed_type  minimum_nights  maximum_nights  availability_365  \
# 0      Real Bed               1              13                73
# 1      Real Bed              30            1124               156
# 2      Real Bed               1            1125                 0
# 3      Real Bed              14              41                35
# 4      Real Bed              60            1125               289
# ...         ...             ...             ...               ...
# 13526  Real Bed               1              14                65
# 13527  Real Bed               6              14                 0
# 13528  Real Bed               4              12                 0
# 13529  Real Bed               2              45               334
# 13530  Real Bed               3              60                19
#
#       property_type is_business_travel_ready cleaning_fee        room_type  \
# 0         Apartment                        f        $0.00     Private room
# 1         Apartment                        f          NaN     Private room
# 2         Apartment                        f       $15.00     Private room
# 3         Apartment                        f       $50.00  Entire home/apt
# 4         Apartment                        f          NaN  Entire home/apt
# ...             ...                      ...          ...              ...
# 13526     Apartment                        f       $50.00  Entire home/apt
# 13527     Apartment                        f        $0.00  Entire home/apt
# 13528     Apartment                        f          NaN     Private room
# 13529     Apartment                        f          NaN     Private room
# 13530     Apartment                        f       $15.00  Entire home/apt
#
#        square_feet  guests_included
# 0              NaN                1
# 1              NaN                1
# 2              NaN                1
# 3              NaN                1
# 4              NaN                1
# ...            ...              ...
# 13526          NaN                1
# 13527          NaN                1
# 13528          NaN                1
# 13529          0.0                1
# 13530          NaN                1
#
# [13531 rows x 20 columns]

# %%
df.shape
# Out:
# (13531, 20)

# %%
# 4.1 show the head (first 5 rows) of dataframe df
df.head()
# Out:
#          id   price neighbourhood_group_cleansed   latitude  longitude  \
# 0  28684898  $50.00                     Neukölln  52.473978  13.454423
# 1  22607348  $10.00           Treptow - Köpenick  52.468095  13.487103
# 2  21019199  $35.00                     Neukölln  52.481810  13.437268
# 3  21919556  $99.00                       Pankow  52.537269  13.416036
# 4   4820648  $39.00     Friedrichshain-Kreuzberg  52.491483  13.387362
#
#    bathrooms  availability_30  beds  bedrooms  review_scores_value  bed_type  \
# 0        1.0               18   2.0       2.0                  9.0  Real Bed
# 1        1.0                0   1.0       1.0                  9.0  Real Bed
# 2        1.0                0   1.0       1.0                  9.0  Real Bed
# 3        2.0                0   2.0       2.0                  NaN  Real Bed
# 4        1.0                0   1.0       1.0                  9.0  Real Bed
#
#    minimum_nights  maximum_nights  availability_365 property_type  \
# 0               1              13                73     Apartment
# 1              30            1124               156     Apartment
# 2               1            1125                 0     Apartment
# 3              14              41                35     Apartment
# 4              60            1125               289     Apartment
#
#   is_business_travel_ready cleaning_fee        room_type  square_feet  \
# 0                        f        $0.00     Private room          NaN
# 1                        f          NaN     Private room          NaN
# 2                        f       $15.00     Private room          NaN
# 3                        f       $50.00  Entire home/apt          NaN
# 4                        f          NaN  Entire home/apt          NaN
#
#    guests_included
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
# 4.2 import matplotlib.pyplot and create a histogram (plt.hist()) from the price column of dataframe df
import matplotlib.pyplot as plt
plt.hist(df["price"], bins=50)
# Out:
# (array([2049., 1801., 1763., 1155., 1250.,  542.,  557.,  872.,  316.,
#          427.,  375.,  255.,  309.,  188.,  132.,  336.,  124.,   90.,
#           94.,  144.,   76.,   25.,   68.,   59.,   35.,   97.,   75.,
#           31.,   23.,   23.,   28.,   12.,   25.,   10.,   28.,   12.,
#           11.,   22.,    9.,   12.,   12.,    6.,   12.,    5.,    6.,
#            6.,    8.,    5.,    5.,    6.]),
#  array([  0.  ,   5.26,  10.52,  15.78,  21.04,  26.3 ,  31.56,  36.82,
#          42.08,  47.34,  52.6 ,  57.86,  63.12,  68.38,  73.64,  78.9 ,
#          84.16,  89.42,  94.68,  99.94, 105.2 , 110.46, 115.72, 120.98,
#         126.24, 131.5 , 136.76, 142.02, 147.28, 152.54, 157.8 , 163.06,
#         168.32, 173.58, 178.84, 184.1 , 189.36, 194.62, 199.88, 205.14,
#         210.4 , 215.66, 220.92, 226.18, 231.44, 236.7 , 241.96, 247.22,
#         252.48, 257.74, 263.  ]),
#  <BarContainer object of 50 artists>)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13531 entries, 0 to 13530
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            13531 non-null  int64
#  1   price                         13531 non-null  object
#  2   neighbourhood_group_cleansed  13531 non-null  object
#  3   latitude                      13531 non-null  float64
#  4   longitude                     13531 non-null  float64
#  5   bathrooms                     13508 non-null  float64
#  6   availability_30               13531 non-null  int64
#  7   beds                          13502 non-null  float64
#  8   bedrooms                      13520 non-null  float64
#  9   review_scores_value           10853 non-null  float64
#  10  bed_type                      13531 non-null  object
#  11  minimum_nights                13531 non-null  int64
#  12  maximum_nights                13531 non-null  int64
#  13  availability_365              13531 non-null  int64
#  14  property_type                 13531 non-null  object
#  15  is_business_travel_ready      13531 non-null  object
#  16  cleaning_fee                  9259 non-null   object
#  17  room_type                     13531 non-null  object
#  18  square_feet                   271 non-null    float64
#  19  guests_included               13531 non-null  int64
# dtypes: float64(7), int64(6), object(7)
# memory usage: 2.1+ MB

# %%
# some cleaning, we come to this topic later
df['price'] = df['price'].str.replace('$','').str.replace(',','').astype(float)
df.head()
# Out:
#          id  price neighbourhood_group_cleansed   latitude  longitude  \
# 0  28684898   50.0                     Neukölln  52.473978  13.454423
# 1  22607348   10.0           Treptow - Köpenick  52.468095  13.487103
# 2  21019199   35.0                     Neukölln  52.481810  13.437268
# 3  21919556   99.0                       Pankow  52.537269  13.416036
# 4   4820648   39.0     Friedrichshain-Kreuzberg  52.491483  13.387362
#
#    bathrooms  availability_30  beds  bedrooms  review_scores_value  bed_type  \
# 0        1.0               18   2.0       2.0                  9.0  Real Bed
# 1        1.0                0   1.0       1.0                  9.0  Real Bed
# 2        1.0                0   1.0       1.0                  9.0  Real Bed
# 3        2.0                0   2.0       2.0                  NaN  Real Bed
# 4        1.0                0   1.0       1.0                  9.0  Real Bed
#
#    minimum_nights  maximum_nights  availability_365 property_type  \
# 0               1              13                73     Apartment
# 1              30            1124               156     Apartment
# 2               1            1125                 0     Apartment
# 3              14              41                35     Apartment
# 4              60            1125               289     Apartment
#
#   is_business_travel_ready cleaning_fee        room_type  square_feet  \
# 0                        f        $0.00     Private room          NaN
# 1                        f          NaN     Private room          NaN
# 2                        f       $15.00     Private room          NaN
# 3                        f       $50.00  Entire home/apt          NaN
# 4                        f          NaN  Entire home/apt          NaN
#
#    guests_included
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
plt.hist(df['price'])
# Out:
# (array([1.3499e+04, 5.0000e+00, 5.0000e+00, 1.0000e+00, 1.0000e+00,
#         2.0000e+00, 1.5000e+01, 0.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([   0.,  900., 1800., 2700., 3600., 4500., 5400., 6300., 7200.,
#         8100., 9000.]),
#  <BarContainer object of 10 artists>)

# %%
# 4.3 add the range parameter to the plt.hist call: plt.hist(...,range=(x_min_value, x_max_value))
x_min_value = df['price'].min()
x_max_value = df['price'].max()

print("min", x_min_value)
print("max", x_max_value)

# x_min_value = 0
# x_max_value = 9000

# plt.hist(df['price'], range=(x_min_value, x_max_value))
# Out:
# min 0.0
# max 9000.0

# %%
df[df['price'] == 0]
# Out:
#             id  price neighbourhood_group_cleansed   latitude  longitude  \
# 3912  20218037    0.0                        Mitte  52.510657  13.379387
# 4283  20317884    0.0                       Pankow  52.536574  13.429483
# 5531  20382969    0.0     Friedrichshain-Kreuzberg  52.521407  13.453777
# 8295  21154484    0.0     Friedrichshain-Kreuzberg  52.509413  13.460555
#
#       bathrooms  availability_30  beds  bedrooms  review_scores_value  \
# 3912        1.0                1   1.0       1.0                  9.0
# 4283        1.0                0   3.0       2.0                 10.0
# 5531        1.0                0   1.0       1.0                 10.0
# 8295        1.0                0   1.0       2.0                  NaN
#
#       bed_type  minimum_nights  maximum_nights  availability_365  \
# 3912  Real Bed               1             120                10
# 4283  Real Bed               2            1125                 0
# 5531  Real Bed               4              14                 0
# 8295  Real Bed               3              10                 0
#
#      property_type is_business_travel_ready cleaning_fee        room_type  \
# 3912     Apartment                        f       $10.00     Private room
# 4283     Apartment                        f       $15.00  Entire home/apt
# 5531     Apartment                        f       $20.00     Private room
# 8295     Apartment                        f       $40.00     Private room
#
#       square_feet  guests_included
# 3912          NaN                1
# 4283          NaN                2
# 5531          NaN                1
# 8295          NaN                3

# %%
df['price'].describe()
# Out:
# count    13531.000000
# mean        70.082625
# std        255.451132
# min          0.000000
# 25%         30.000000
# 50%         45.000000
# 75%         70.000000
# max       9000.000000
# Name: price, dtype: float64

# %%
plt.hist(df[df['price'] < 500]['price'], bins=100)
plt.xlabel('Price')
plt.ylabel('Jumlah listing')
plt.title('Distribusi Harga < $500')
# Out:
# Text(0.5, 1.0, 'Distribusi Harga < $500')

# %%
df[df['price'] > 500].shape
# Out:
# (53, 20)

# %%
# 4.4 create a scatter plot with plt.scatter(x,y)
# where x is the price column from df and y the square_feet column

# Filter data agar hanya ambil baris dengan nilai square_feet yang valid
df_filtered = df[df['square_feet'].notnull()]

# Buat scatter plot
plt.figure(figsize=(10,6))
plt.scatter(df_filtered['price'], df_filtered['square_feet'], alpha=0.5)
plt.xlabel('Price ($)')
plt.ylabel('Square Feet')
plt.title('Scatter Plot: Price vs Square Feet')
plt.grid(True)
plt.show()

# %%
# Boxplot untuk kolom 'price'
plt.figure(figsize=(8, 6))
plt.boxplot(df['price'], vert=False)
plt.xlabel('Price ($)')
plt.title('Boxplot Harga')
plt.grid(True)
plt.show()
